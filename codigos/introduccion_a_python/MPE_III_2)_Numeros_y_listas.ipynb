# %% [markdown]
# <a href="https://colab.research.google.com/github/mateosuster/pythonungs/blob/master/codigos/introduccion_a_python/MPE_III_2)_Numeros_y_listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Números enteros y flotantes
#
# Con los números se pueden realizar los siguientes tipos de operaciones:
#
# | Operación | Resultado       |
# | --------- | --------------- |
# |    +      | Suma            |
# |    -      | Resta           |
# |    *      | Multiplicación  |
# |    /      | División        |
# |    //     | División entera |
# |    \*\*   | Potencia        |
# |    %   | Resto        |
#
# Algunos sencillos ejemplos son:

# %%
2**2
# Out:
# 4

# %%
2**5
# Out:
# 32

# %%
3/2
# Out:
# 1.5

# %%
3./2
# Out:
# 1.5

# %%
3//2
# Out:
# 1

# %%
3%2
# Out:
# 1

# %%
61%2
# Out:
# 1

# %%
2//3
# Out:
# 0

# %% [markdown]
# Prestar atención a la diferencia entre el tipo de dato entero y flotante

# %%
type(2)
# Out:
# int

# %%
type(2.)
# Out:
# float

# %% [markdown]
# Podemos asignar valores a determinados objetos/variables para realizar operaciones o transformaciones con ellos

# %%
#defino los parámetros
base = 200
altura = 100

#realizo el cálculo
area = base * altura

#imprimo el resultado
print(area)
# Out:
# 20000

# %% [markdown]
# Podemos mejorar el `print` con algunos detalles

# %%
print("El area es igual a ", area, '.', sep='')
# Out:
# El area es igual a 20000.

# %% [markdown]
# Cuando queremos operar con números, es importante guardar correctamente los datos como **tipo numérico**, porque sino el programa se rompe. Veáse el siguiente ejemplo donde se intenta restar un tipo de dato float a uno string (o cadena, que veremos más adelante):

# %%
numero = 4.20
string="420"

string - numero
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_45059/4288905913.py in <cell line: 0>()
#       2 string="420"
#       3
# ----> 4 string - numero
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
float(string) - numero

# %% [markdown]
# Para saber con qué tipo de dato estamos trabajando, podemos hacer uso de la función `type()`

# %%
print("el objeto 'numero' es", type(numero),
      "\nmientras que el objeto string es", type(string))

# %% [markdown]
# # Listas
#
# Las listas son arreglos de datos que poseen las siguientes caracteristicas:
#
# * Ordenadas: Mantienen el orden en el que se insertan los elementos.
#
# * Indexadas: Se accede a cada elemento mediante un índice numérico (empezando desde el 0).
#
# * Mutables: Su contenido puede modificarse (añadir, eliminar o cambiar elementos) después de haber sido creada.
#
# * Dinámicas: Pueden crecer o achicarse en tamaño según sea necesario, sin necesidad de definir un tamaño fijo de antemano.
#
# * Heterogéneas: Tienen la capacidad de almacenar diferentes tipos de datos de forma simultánea (enteros, strings, booleanos, etc.).
#
# * Permiten duplicados: Un mismo valor puede aparecer en múltiples posiciones dentro de la misma lista.
#
# * Anidables: Una lista puede contener otras listas como elementos, permitiendo crear estructuras multidimensionales.
#
# Se definen con corchetes, y pueden contener datos de distintos tipos (números enteros y flotantes, o también los tipos que veremos más abajo). Un ejemplo de una lista en Python es:

# %%
li = [-5, 7, 4, 9, 1, 12, 12., 2] #Asigno al objeto llamado 'li' una lista de números enteros

# %%
print(li)
# Out:
# [-5, 7, 4, 9, 1, 12, 12.0, 2]

# %% [markdown]
# La operación más importante que se hace con las listas es la extracción de sus elementos en distintas posiciones. Es muy importante tener en cuenta que las listas en Python siempre empiezan con el índice `0`. Otros lenguajes de programación (C, C++ o R, por ejemplo) pueden comenzar la inicialización de sus listas en '1'.

# %%
li[0]

# %%
li[5]

# %%
li[-2]

# %%
# Vamos a evaluar si es el mismo numero este indexing
li[-2] == li[6]

# %% [markdown]
# Lo bueno de las listas en Python es que si usamos un índice más grande que `n-1`, donde `n` es el total de elementos, Python nos da un error.

# %%
li[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_45059/879168620.py in <cell line: 0>()
# ----> 1 li[20]
#
# IndexError: list index out of range

# %% [markdown]
# Recordemos que podemos conocer la longitud de la lista con la funcion `len()`

# %%
len(li)
# Out:
# 9

# %% [markdown]
# Podemos utilizar la función `help()` para saber qué hace una función determinada.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# Si nos es de utilidad, podemos guardar la longitud de la lista en una nueva variable

# %%
largo = len(li)

# %%
li[largo-1]
# Out:
# 99

# %% [markdown]
# Las listas son modificables, es decir, que sus elementos pueden modificarse de acuerdo a la siguiente sintaxis:

# %%
li
# Out:
# [-5, 7, 4, 9, 1, 'que aburrido este vierness', 12.0, 2]

# %%
li[-3] = 'que aburrido este vierness'

# %%
li
# Out:
# [-5, 7, 4, 9, 1, 'que aburrido este vierness', 12.0, 2]

# %% [markdown]
# ## Métodos útiles

# %% [markdown]
# ### .append()

# %% [markdown]
# También podemos agregar un elemento cualquiera al final de una lista con la funcion `append()`. Para aplicarla sobre la lista actual (`li`) debemos mencionarla seguida de un `.` y posteriormente el nombre de la función.

# %%
li.append(99)

# %%
print(li)
# Out:
# [-5, 7, 4, 9, 1, 12, 12.0, 2, 99, 99, 99, 99, 99]

# %% [markdown]
# Esto nos puede ser de utilidad, por ejemplo, cuando queremos agregarle elementos a una lista vacía

# %%
lista_vacia = []
lista_vacia
# Out:
# []

# %%
lista_vacia.append("algo")
print("la lista vacía ahora tiene", lista_vacia)
# Out:
# la lista vacía ahora tiene ['algo']

# %% [markdown]
# ### .insert()

# %% [markdown]
# También se puede utilizar el método `.insert()` para introducir algun dato en una lista dentro de una posicion determinada.

# %%
fruit = ["banana","cherry","grape"]

# %%
fruit.insert(1,["apple", "manzana", "steve jobs"]*3)
print(fruit)
# Out:
# ['banana', ['apple', 'manzana', 'steve jobs', 'apple', 'manzana', 'steve jobs', 'apple', 'manzana', 'steve jobs'], 'cherry', 'grape']

# %%
fruit[1][2]
# Out:
# 'steve jobs'

# %% [markdown]
# ## Slicing

# %% [markdown]
# Además pueden seleccionarse fácilmente subconjuntos de una lista, usando lo que se conoce como *rebanado* (o *slicing* en inglés), que consiste en usar dos índices separados por `:` al momento de tomar elementos de la lista. Al hacerlo, Python toma los elementos que van desde el primer índice hasta uno menos del último índice elegido (es decir, su límite superior es exclusivo).
#
#
# ```
# lista[desde_inclusivo : hasta_exclusivo]
# ```
#
#
# Veamos un par de ejemplos:

# %%
li
# Out:
# [-5, 7, 4, 9, 1, 12, 12.0, 2, 99, 99, 99, 99, 99]

# %%
li[2:6]
# Out:
# [4, 9, 1, 12]

# %%
li[6]
# Out:
# 12.0

# %% [markdown]
# El rebanado también funciona si se usa un sólo índice, bien sea el superior o el inferior, siempre que vaya acompañado de los `:`. En estos casos se obtiene el resultado que uno esperaría, es decir, que se tome desde el índice que uno quiera hasta el final:

# %%
li[2:]
# Out:
# [4, 9, 1, 'que aburrido este vierness', 12.0, 2, 99]

# %% [markdown]
# o lo opuesto: que la selección vaya desde el principio hasta un índice menos que el que se use como último:

# %%
li[:4]
# Out:
# [-5, 7, 4, 9]

# %% [markdown]
# Es importante mencionar que la selección de elementos y el rebanado también funcionan con índices negativos.
#
# <br>
#
# ![](https://qph.fs.quoracdn.net/main-qimg-a380b1bc159589df5e0b9842e5b56b6d)

# %%
li[-4]
# Out:
# 'que aburrido este vierness'

# %%
li[-3:]
# Out:
# [99, 99, 99]

# %%
li[:8]
# Out:
# [-5, 7, 4, 9, 1, 12, 12.0, 2]

# %% [markdown]
# ## Operaciones con listas

# %% [markdown]
# ### Concatenación

# %% [markdown]
# Finalmente cabe decir que se pueden usar las operaciones aritméticas `+` para concatenar dos listas, y `*` para repetir varias veces los elementos de una lista, así:

# %%
lista_1 = [0, 4, 7]
lista_2 = [2, 3]
lista_1 + lista_2
# Out:
# [0, 4, 7, 2, 3]

# %%
li + [1, 2, "cosita"]
# Out:
# [-5, 7, 4, 9, 1, 12, 12.0, 2, 99, 99, 99, 99, 99, 1, 2, 'cosita']

# %% [markdown]
# ### "Multiplicación"

# %%
li
# Out:
# [-5, 7, 4, 9, 1, 12, 12.0, 2, 99, 99, 99, 99, 99]

# %%
print(li *3)
# Out:
# [-5, 7, 4, 9, 1, 12, 12.0, 2, 99, 99, 99, 99, 99, -5, 7, 4, 9, 1, 12, 12.0, 2, 99, 99, 99, 99, 99, -5, 7, 4, 9, 1, 12, 12.0, 2, 99, 99, 99, 99, 99]

# %%
[0] * 4
# Out:
# [0, 0, 0, 0]
