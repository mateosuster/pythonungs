# %% [markdown]
# <a href="https://colab.research.google.com/github/mateosuster/pythonungs/blob/master/codigos/introduccion_a_python/MPE_III_1)_Sintaxis_b%C3%A1sica_y_asignaci%C3%B3n_de_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tipos de datos

# %% [markdown]
# ## Enteros (int)

# %%
400
# Out:
# 400

# %%
type(400)
# Out:
# int

# %% [markdown]
# ## Flotantes/Reales (float)

# %%
400.4
# Out:
# 400.4

# %%
400.0
# Out:
# 400.0

# %%
type(400.0)
# Out:
# float

# %%
type(200.)
# Out:
# float

# %%
10 + 2
# Out:
# 12

# %%
10 + 2.
# Out:
# 12.0

# %% [markdown]
# ## Texto/String (str)

# %%
"10"
# Out:
# '10'

# %%
'Bienvenidos al Curso'
# Out:
# 'Bienvenidos al Curso'

# %%
type('10')
# Out:
# str

# %%
"Hola" + ' mundo'
# Out:
# 'Hola mundo'

# %% [markdown]
# Veamos ahora el *bautismo pythónico* inicial: digámosle "Hola" al mundo!

# %%
print("Hola mundo!")
# Out:
# Hola mundo!

# %% [markdown]
# ## Booleanos (bool)

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %% [markdown]
# # Operaciones logicas

# %%
2 < 4
# Out:
# True

# %%
2 > 4
# Out:
# False

# %%
2 <= 3
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %%
2 != 3
# Out:
# True

# %%
2 == 2
# Out:
# True

# %%
type(2 == 2)
# Out:
# bool

# %% [markdown]
# ## Asignación de variables
#
# `variable = expresion`

# %%
pi = 3.14

# %% [markdown]
# Podemos usar la función `print()` para imprimir por pantalla, aunque también es posible relizarlo solo invocando los objetos creados (aunque esto no es tan frecuente, incluso podría ser considerado por algunes como una *mala práctica*)

# %%
print(pi)
# Out:
# 3.14

# %%
pi = 503.14
print(pi)
# Out:
# 503.14

# %%
pi * 100
# Out:
# 50314.0

# %%
# esto es un comentario, el cual no es leído por el programa

pi / 420 # podemos introducir comentarios en cualquier lugar seguido de un numeral ("#")
# Out:
# 1.1979523809523809

# %%
# print(pi + 420 ) # esto tiene pinta de ser codigo pero se encuentra "comentado"

# %%
lo_que_se_me_antoja = 5634.634 / 135253 + 35345 * 34353356
print(lo_que_se_me_antoja)
print('-'*10)
otro_antojo = lo_que_se_me_antoja - 1214219367820.0417
print(otro_antojo)
# Out:
# 1214219367820.0417
# ----------
# 0.0

# %% [markdown]
# Python (como muchos otros lenguajes) distingue mayúsculas y minúsculas, por lo que hay que tener cuidado a la hora de asignarles un nombre. Es importante también que las variables tengan nombres declarativos.

# %%
Variable=5
variable=3
VaRiAbLe=8
VARIABLE=1
# Son todas variables distintas !

# %% [markdown]
# Hay que tener cuidado con los **estados** de las variables, ya que pueden ir modificándose a lo largo del algoritmo.
#
# Por ejemplo, la variable `papita` puede empezar valiendo 5....

# %%
papita = 5
print(papita)
# Out:
# 5

# %% [markdown]
# Pero puede terminar valiendo otra cosa...

# %%
papita = 18
print(papita)
# Out:
# 18

# %% [markdown]
# Siempre tomará el último valor asignado (los estados anteriores se pierden)

# %%
papita = "frita"
print(papita)
# Out:
# frita
