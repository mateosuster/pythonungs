# %%
import pandas as pd 

file_path = r"C:\Users\mateo\Documents\teaching\UNGS\2302\file.xls"

# com1 = pd.read_csv(r'C:\Users\mateo\Documents\docencia\ungs\2301\comi1.xls - Reporte.csv')
com1 = pd.read_excel(file_path)

com1
# Out:
# _locate_stream(Workbook): seen
#     0  5 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 3 2
# ---------------------------------------------------------------------------
# CompDocError                              Traceback (most recent call last)
# c:\Users\mateo\Documents\data\repos\pythonungs\codigos\correccciones.ipynb Cell 1 line <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/mateo/Documents/data/repos/pythonungs/codigos/correccciones.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> file_path = r"C:\Users\mateo\Documents\teaching\UNGS\2302\file.xls"
#       <a href='vscode-notebook-cell:/c%3A/Users/mateo/Documents/data/repos/pythonungs/codigos/correccciones.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> # com1 = pd.read_csv(r'C:\Users\mateo\Documents\docencia\ungs\2301\comi1.xls - Reporte.csv')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mateo/Documents/data/repos/pythonungs/codigos/correccciones.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> com1 = pd.read_excel(file_path)
# ...

# %%
import xlrd

workbook = xlrd.open_workbook(file_path)
# Out:
# _locate_stream(Workbook): seen
#     0  5 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 3 2
# ---------------------------------------------------------------------------
# CompDocError                              Traceback (most recent call last)
# c:\Users\mateo\Documents\data\repos\pythonungs\codigos\correccciones.ipynb Cell 2 line <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/mateo/Documents/data/repos/pythonungs/codigos/correccciones.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import xlrd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mateo/Documents/data/repos/pythonungs/codigos/correccciones.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> workbook = xlrd.open_workbook(file_path)
#
# File c:\Users\mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\xlrd\__init__.py:172, in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     169 if file_format and file_format != 'xls':
# ...
